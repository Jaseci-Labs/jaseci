# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/facebook/bart-large"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": "Today is a sunny day and I'll get some ice cream.",
})

# %%
output
# Out:
# [[[0.031958553940057755,
#    0.5005658864974976,
#    -0.3453701138496399,
#    0.2829972505569458,
#    -0.14698666334152222,
#    -0.6116330623626709,
#    -0.3783007264137268,
#    -0.5159279108047485,
#    -0.06192651018500328,
#    -0.1356484293937683,
#    -0.03565475717186928,
#    -0.451358437538147,
#    -1.3190914392471313,
#    -0.45307785272598267,
#    -0.04598070681095123,
#    0.4496678113937378,
#    0.5350236296653748,
#    -0.42050978541374207,
#    -0.16616010665893555,
#    -0.42777562141418457,
#    4.975521564483643,
#    -0.37268996238708496,
#    0.002526290249079466,
#    0.172051340341568,
#    -0.6161962151527405,
#    -0.08098789304494858,
#    -0.003587997518479824,
#    -0.7588995695114136,
#    -0.5057393908500671,
#    0.023553846403956413,
#    0.31613650918006897,
#    -0.34744080901145935,
#    0.17404866218566895,
#    -0.03981989249587059,
#    0.3621295988559723,
#    0.03658575564622879,
#    -0.47655802965164185,
#    -0.5450547337532043,
# ...

# %%
x = ["apple", "pineapple"]
y = {
    "pineapple": 2,
    "apple": 1
    
}

y.keys() == set(x)
# Out:
# True

# %%
def check(**kwargs):
    print(kwargs)

# %%
check(apple=1, pineapple=2)
# Out:
# {'apple': 1, 'pineapple': 2}
